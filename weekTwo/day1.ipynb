# %%
from openai import OpenAI
import gradio as gr

# %%
client = OpenAI(base_url="http://localhost:11434/v1", api_key="anything")

MODEL = "llama3.2"

system_message= "You are flight AI assistance, a helpful customer support assistance. Give Short and brief answers"

# %%
def chat(message , history):
    messages= [
        {"role":"system" , "content":system_message }
    ] 

    for user_message , assistant_message in history:
        messages.append(
            {
                "role": "user",
                "content":user_message
            }
        )

    messages.append({
        "role": "assistant" , "content": assistant_message
    })

    messages.append(
        {
            "role": "user",
            "content": message
        }
    )


    response = client.chat.completions.create(
        model = MODEL,
        messages = messages
    )

    return response.choices[0].message.content

gr.ChatInterface(
    fn= chat
).launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Traceback (most recent call last):
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\queueing.py", line 882, in process_events
#     response = await route_utils.call_process_api(
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<5 lines>...
#     )
#     ^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\route_utils.py", line 417, in call_process_api
#     output = await app.get_blocks().process_api(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<12 lines>...
#     )
#     ^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\blocks.py", line 2430, in process_api
#     result = await self.call_function(
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#     ...<9 lines>...
#     )
#     ^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\blocks.py", line 1696, in call_function
#     prediction = await fn(*processed_input)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\utils.py", line 1083, in async_wrapper
#     response = await f(*args, **kwargs)
#                ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\chat_interface.py", line 544, in __wrapper
#     return await submit_fn(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\gradio\chat_interface.py", line 936, in _submit_fn
#     response = await run_sync(self.fn, *inputs, limiter=self.limiter)  # type: ignore
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\anyio\to_thread.py", line 65, in run_sync
#     return await get_async_backend().run_sync_in_worker_thread(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         func, args, abandon_on_cancel=abandon_on_cancel, limiter=limiter
#         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#     )
#     ^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 2706, in run_sync_in_worker_thread
#     return await future
#            ^^^^^^^^^^^^
#   File "c:\Users\Shahab Comp KTA\OneDrive\Desktop\LLM_Implementation\.venv\Lib\site-packages\anyio\_backends\_asyncio.py", line 1100, in run
#     result = context.run(func, *args)
#   File "C:\Users\Shahab Comp KTA\AppData\Local\Temp\ipykernel_24612\4176282197.py", line 15, in chat
#     "role": "assistance" , "content": assistance_message
#                                       ^^^^^^^^^^^^^^^^^^
# UnboundLocalError: cannot access local variable 'assistance_message' where it is not associated with a value
